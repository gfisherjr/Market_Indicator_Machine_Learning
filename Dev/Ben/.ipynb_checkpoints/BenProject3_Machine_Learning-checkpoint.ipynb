# %% [markdown]
# ## Machine Learning - Market Indicators

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import scipy.stats as sts
# import quandl
import os
import numpy as np
from scipy import stats
from scipy.stats import linregress
from scipy.stats import pearsonr

# %%
import quandl
from config import api_key

# %% [markdown]
# ## Importing Raw Data from Quandl

# %%
try:
    B_Spread = quandl.get("ML/BEY", authtoken=api_key)
    Treasury_curve = quandl.get("USTREASURY/YIELD", authtoken=api_key)
    SP500 = quandl.get("CHRIS/CME_ES2", authtoken = api_key)
    EM_Yields = quandl.get("ML/EMHYY", authtoken = api_key)
    
    # Saving CSV
    B_Spread.to_csv('B_Spread.csv')
    Treasury_curve.to_csv('Treasury_curve.csv')
    SP500.to_csv('SP500.csv')
    EM_Yields.to_csv('EM_Yields.csv')
    
except Exception as e:
    print(e)

# %% [markdown]
# ## Importing CSV data

# %%
# Importing data 
B_Spread = pd.read_csv('B_Spread.csv')
Treasury_curve = pd.read_csv('Treasury_curve.csv')
SP500 = pd.read_csv('SP500.csv')
EM_Yields = pd.read_csv('EM_Yields.csv')
Nikkei = pd.read_csv('Nikkei.csv')
Ted_Spread = pd.read_csv('Ted_Spread.csv')
USDJPY = pd.read_csv('USDJPY.csv')
VIX = pd.read_csv('VIX.csv')

# %% [markdown]
# ## Formatting

# %% [markdown]
# ## SP500
# • Calculating the Returns
#
# • Calculating Historical Vols with different time horizons

# %%
# Create a SP500 data frame with price only
SP500_Price = pd.DataFrame({'Date':SP500['Date'],
                           'Closing_Price': SP500['Settle']
                           })
# Vol calculation
SP500_Price['Daily_Return'] = SP500_Price['Closing_Price'].pct_change() #Daily return

SP500_Price['20-day_Vol']= SP500_Price['Daily_Return'].rolling(20).std() * np.sqrt(252)*100 # 20-day vol
SP500_Price['50-day_Vol']= SP500_Price['Daily_Return'].rolling(50).std() * np.sqrt(252)*100 # 50-day vol
SP500_Price['100-day_Vol']= SP500_Price['Daily_Return'].rolling(100).std() * np.sqrt(252)*100 # 100-day vol                                                                         

# MA calculation
SP500_Price['21-day_MA']= SP500_Price['Closing_Price'].rolling(21).mean()
SP500_Price['55-day_MA']= SP500_Price['Closing_Price'].rolling(55).mean()
SP500_Price['100-day_MA']= SP500_Price['Closing_Price'].rolling(100).mean()

# Formatting the date
SP500_Price['Date'] = pd.to_datetime(SP500_Price['Date'])

# %%
SP500_Price
# Out:
#            Date  Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  \
# 0    1997-09-09         944.00           NaN         NaN         NaN
# 1    1997-09-10         925.00     -0.020127         NaN         NaN
# 2    1997-09-11         918.25     -0.007297         NaN         NaN
# 3    1997-09-12         933.75      0.016880         NaN         NaN
# 4    1997-09-15         931.50     -0.002410         NaN         NaN
# ...         ...            ...           ...         ...         ...
# 5810 2020-07-09        3130.50     -0.007057   27.936183   25.146713
# 5811 2020-07-10        3167.50      0.011819   19.276800   24.660182
# 5812 2020-07-13        3137.50     -0.009471   19.642138   24.560830
# 5813 2020-07-14        3172.75      0.011235   19.545827   23.688066
# 5814 2020-07-15        3208.50      0.011268   18.901618   23.767095
#
#       100-day_Vol    21-day_MA    55-day_MA  100-day_MA
# 0             NaN          NaN          NaN         NaN
# 1             NaN          NaN          NaN         NaN
# 2             NaN          NaN          NaN         NaN
# 3             NaN          NaN          NaN         NaN
# 4             NaN          NaN          NaN         NaN
# ...           ...          ...          ...         ...
# 5810    49.192179  3088.047619  2995.604545   2892.7000
# 5811    49.226894  3087.666667  3002.631818   2890.6775
# 5812    49.240854  3094.238095  3009.259091   2888.1725
# 5813    49.267736  3101.333333  3015.645455   2886.2025
# 5814    49.279935  3108.309524  3021.963636   2884.8925
#
# [5815 rows x 9 columns]

# %% [markdown]
# ## SP500 Vol Plot

# %%
fig = plt.figure(figsize = (20,10))

plt.plot(SP500_Price['Date'],SP500_Price['20-day_Vol'],'-g', label="20 day Vol")
plt.grid(True)
plt.title('SP500 Historical Vol')
# Out:
# Text(0.5, 1.0, 'SP500 Historical Vol')

# %%
SP500_Price
# Out:
#            Date  Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  \
# 0    1997-09-09         944.00           NaN         NaN         NaN
# 1    1997-09-10         925.00     -0.020127         NaN         NaN
# 2    1997-09-11         918.25     -0.007297         NaN         NaN
# 3    1997-09-12         933.75      0.016880         NaN         NaN
# 4    1997-09-15         931.50     -0.002410         NaN         NaN
# ...         ...            ...           ...         ...         ...
# 5810 2020-07-09        3130.50     -0.007057   27.936183   25.146713
# 5811 2020-07-10        3167.50      0.011819   19.276800   24.660182
# 5812 2020-07-13        3137.50     -0.009471   19.642138   24.560830
# 5813 2020-07-14        3172.75      0.011235   19.545827   23.688066
# 5814 2020-07-15        3208.50      0.011268   18.901618   23.767095
#
#       100-day_Vol    21-day_MA    55-day_MA  100-day_MA
# 0             NaN          NaN          NaN         NaN
# 1             NaN          NaN          NaN         NaN
# 2             NaN          NaN          NaN         NaN
# 3             NaN          NaN          NaN         NaN
# 4             NaN          NaN          NaN         NaN
# ...           ...          ...          ...         ...
# 5810    49.192179  3088.047619  2995.604545   2892.7000
# 5811    49.226894  3087.666667  3002.631818   2890.6775
# 5812    49.240854  3094.238095  3009.259091   2888.1725
# 5813    49.267736  3101.333333  3015.645455   2886.2025
# 5814    49.279935  3108.309524  3021.963636   2884.8925
#
# [5815 rows x 9 columns]

# %% [markdown]
# ## Treasury Curve Data Frame - Calculations
# • Create a new data frame with the key rates only
#
# • Adding the most liquid curve spreads 2s5s, 2s10s, 10s30s

# %%
# Create a new df with the key rates (2,5,10,30 year rates)
Curve_Spreads = pd.DataFrame({'Date':Treasury_curve['Date'],
                             '2Y':Treasury_curve['2 YR'],
                             '5Y':Treasury_curve['5 YR'],
                             '10Y': Treasury_curve['10 YR'],
                              '30Y':Treasury_curve['30 YR']
                             })

# Adding Curve Spreads
Curve_Spreads['2s5s'] = (Curve_Spreads['5Y'] - Curve_Spreads['2Y'])*100
Curve_Spreads['5s10s'] = (Curve_Spreads['10Y'] - Curve_Spreads['5Y'])*100
Curve_Spreads['10s30s'] = (Curve_Spreads['30Y'] - Curve_Spreads['10Y'])*100
Curve_Spreads['2s10s'] = (Curve_Spreads['10Y'] - Curve_Spreads['2Y'])*100

# Calculating Spread Returns
Curve_Spreads['2s5s_Return'] = Curve_Spreads['2s5s'].pct_change()
Curve_Spreads['5s10s_Return'] = Curve_Spreads['5s10s'].pct_change()
Curve_Spreads['10s30s_Return'] = Curve_Spreads['10s30s'].pct_change()
Curve_Spreads['2s10s_Return'] = Curve_Spreads['2s10s'].pct_change()

# Calculating Spread Volatility - 20 day
Curve_Spreads['2s5s_20-day_Vol']= Curve_Spreads['2s5s_Return'].rolling(20).std() * np.sqrt(252)*100 
Curve_Spreads['5s10s_20-day_Vol']= Curve_Spreads['5s10s_Return'].rolling(20).std() * np.sqrt(252)*100 
Curve_Spreads['10s30s_20-day_Vol']= Curve_Spreads['10s30s_Return'].rolling(20).std() * np.sqrt(252)*100
Curve_Spreads['2s10s_20-day_Vol']= Curve_Spreads['2s10s_Return'].rolling(20).std() * np.sqrt(252)*100


# MA calculation-----------------------------------------------------------------------------------------------------------
# 2s5s Spread
Curve_Spreads['2s5s_21-day_MA']= Curve_Spreads['2s5s'].rolling(21).mean()
Curve_Spreads['2s5s_55-day_MA']= Curve_Spreads['2s5s'].rolling(55).mean()
Curve_Spreads['2s5s_100-day_MA']= Curve_Spreads['2s5s'].rolling(100).mean()

# 5s10s Spread
Curve_Spreads['5s10s_21-day_MA']= Curve_Spreads['5s10s'].rolling(21).mean()
Curve_Spreads['5s10s_55-day_MA']= Curve_Spreads['5s10s'].rolling(55).mean()
Curve_Spreads['5s10s_100-day_MA']= Curve_Spreads['5s10s'].rolling(100).mean()

# 10s30s Spread
Curve_Spreads['10s30s_21-day_MA']= Curve_Spreads['10s30s'].rolling(21).mean()
Curve_Spreads['10s30s_55-day_MA']= Curve_Spreads['10s30s'].rolling(55).mean()
Curve_Spreads['10s30s_100-day_MA']= Curve_Spreads['10s30s'].rolling(100).mean()

# 2s10s Spread
Curve_Spreads['2s10s_21-day_MA']= Curve_Spreads['2s10s'].rolling(21).mean()
Curve_Spreads['2s10s_55-day_MA']= Curve_Spreads['2s10s'].rolling(55).mean()
Curve_Spreads['2s10s_100-day_MA']= Curve_Spreads['2s10s'].rolling(100).mean()


# Formatting the date
Curve_Spreads['Date'] = pd.to_datetime(Curve_Spreads['Date'])

# %%
Curve_Spreads
# Out:
#            Date    2Y    5Y   10Y   30Y  2s5s  5s10s  10s30s  2s10s  \
# 0    1990-01-02  7.87  7.87  7.94  8.00   0.0    7.0     6.0    7.0
# 1    1990-01-03  7.94  7.92  7.99  8.04  -2.0    7.0     5.0    5.0
# 2    1990-01-04  7.92  7.91  7.98  8.04  -1.0    7.0     6.0    6.0
# 3    1990-01-05  7.90  7.92  7.99  8.06   2.0    7.0     7.0    9.0
# 4    1990-01-08  7.90  7.92  8.02  8.09   2.0   10.0     7.0   12.0
# ...         ...   ...   ...   ...   ...   ...    ...     ...    ...
# 7636 2020-07-10  0.16  0.30  0.65  1.33  14.0   35.0    68.0   49.0
# 7637 2020-07-13  0.16  0.30  0.64  1.33  14.0   34.0    69.0   48.0
# 7638 2020-07-14  0.14  0.28  0.63  1.30  14.0   35.0    67.0   49.0
# 7639 2020-07-15  0.16  0.28  0.64  1.33  12.0   36.0    69.0   48.0
# 7640 2020-07-16  0.16  0.28  0.62  1.31  12.0   34.0    69.0   46.0
#
#        2s5s_Return  ...  2s5s_100-day_MA  5s10s_21-day_MA  5s10s_55-day_MA  \
# 0              NaN  ...              NaN              NaN              NaN
# 1             -inf  ...              NaN              NaN              NaN
# 2    -5.000000e-01  ...              NaN              NaN              NaN
# 3    -3.000000e+00  ...              NaN              NaN              NaN
# 4     0.000000e+00  ...              NaN              NaN              NaN
# ...            ...  ...              ...              ...              ...
# 7636  1.666667e-01  ...            14.28        37.000000        35.000000
# 7637  0.000000e+00  ...            14.43        37.000000        35.181818
# 7638  2.220446e-16  ...            14.59        36.857143        35.381818
# 7639 -1.428571e-01  ...            14.75        36.761905        35.563636
# 7640  0.000000e+00  ...            14.92        36.428571        35.727273
#
#       5s10s_100-day_MA  10s30s_21-day_MA  10s30s_55-day_MA  10s30s_100-day_MA  \
# 0                  NaN               NaN               NaN                NaN
# 1                  NaN               NaN               NaN                NaN
# 2                  NaN               NaN               NaN                NaN
# 3                  NaN               NaN               NaN                NaN
# 4                  NaN               NaN               NaN                NaN
# ...                ...               ...               ...                ...
# 7636             30.91         74.571429         71.890909              65.38
# 7637             31.10         74.285714         72.109091              65.62
# 7638             31.30         73.952381         72.290909              65.84
# 7639             31.50         73.714286         72.490909              66.09
# 7640             31.67         73.238095         72.690909              66.32
#
#       2s10s_21-day_MA  2s10s_55-day_MA  2s10s_100-day_MA
# 0                 NaN              NaN               NaN
# 1                 NaN              NaN               NaN
# 2                 NaN              NaN               NaN
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 7636        50.809524        50.981818             45.19
# 7637        50.857143        51.145455             45.53
# 7638        50.714286        51.345455             45.89
# 7639        50.523810        51.436364             46.25
# 7640        50.142857        51.509091             46.59
#
# [7641 rows x 29 columns]

# %% [markdown]
# ## Emerging Markets Bond Yields

# %% [markdown]
# ## Formatting

# %%
# Formatting the dates
EM_Yields['DATE'] = pd.to_datetime(EM_Yields['DATE'])

# %%
EM_Yields
# Out:
#            DATE  BAMLEMHBHYCRPIEY
# 0    1998-12-31             14.92
# 1    1999-01-04             14.90
# 2    1999-01-05             14.89
# 3    1999-01-06             14.79
# 4    1999-01-07             14.78
# ...         ...               ...
# 5619 2020-07-09              7.48
# 5620 2020-07-10              7.51
# 5621 2020-07-13              7.49
# 5622 2020-07-14              7.52
# 5623 2020-07-15              7.47
#
# [5624 rows x 2 columns]

# %% [markdown]
# ## EM Yields Calculations

# %%
# Calculating the returns
EM_Yields['EM Returns'] = EM_Yields['BAMLEMHBHYCRPIEY'].pct_change()

# Calculating the 20, 50 and 100 day vol
EM_Yields['EM_Bonds_20-day_Vol']= EM_Yields['EM Returns'].rolling(20).std() * np.sqrt(252)*100 
EM_Yields['EM_Bonds_50-day_Vol']= EM_Yields['EM Returns'].rolling(50).std() * np.sqrt(252)*100 
EM_Yields['EM_Bonds_100-day_Vol']= EM_Yields['EM Returns'].rolling(100).std() * np.sqrt(252)*100 

# Calculating the 21, 55 and 100 day MA
EM_Yields['EM_Bonds_21-day_MA']= EM_Yields['BAMLEMHBHYCRPIEY'].rolling(21).mean() 
EM_Yields['EM_Bonds_55-day_MA']= EM_Yields['BAMLEMHBHYCRPIEY'].rolling(55).mean() 
EM_Yields['EM_Bonds_100-day_MA']= EM_Yields['BAMLEMHBHYCRPIEY'].rolling(100).mean()


EM_Yields
# Out:
#            DATE  BAMLEMHBHYCRPIEY  EM Returns  EM_Bonds_20-day_Vol  \
# 0    1998-12-31             14.92         NaN                  NaN
# 1    1999-01-04             14.90   -0.001340                  NaN
# 2    1999-01-05             14.89   -0.000671                  NaN
# 3    1999-01-06             14.79   -0.006716                  NaN
# 4    1999-01-07             14.78   -0.000676                  NaN
# ...         ...               ...         ...                  ...
# 5619 2020-07-09              7.48    0.002681            13.489328
# 5620 2020-07-10              7.51    0.004011            13.639344
# 5621 2020-07-13              7.49   -0.002663            12.136466
# 5622 2020-07-14              7.52    0.004005            10.228824
# 5623 2020-07-15              7.47   -0.006649            10.299046
#
#       EM_Bonds_50-day_Vol  EM_Bonds_100-day_Vol  EM_Bonds_21-day_MA  \
# 0                     NaN                   NaN                 NaN
# 1                     NaN                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 3                     NaN                   NaN                 NaN
# 4                     NaN                   NaN                 NaN
# ...                   ...                   ...                 ...
# 5619            18.095147             48.200708            7.758571
# 5620            17.999389             48.135374            7.737619
# 5621            17.939409             48.140856            7.715238
# 5622            18.040676             48.047347            7.689048
# 5623            17.960005             47.830196            7.669048
#
#       EM_Bonds_55-day_MA  EM_Bonds_100-day_MA
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ...                  ...                  ...
# 5619            8.616000               9.1899
# 5620            8.561455               9.2041
# 5621            8.507818               9.2178
# 5622            8.457091               9.2305
# 5623            8.411455               9.2407
#
# [5624 rows x 9 columns]

# %% [markdown]
# ## VIX

# %%
# Formatting the dates 
VIX['Date'] = pd.to_datetime(VIX['Date'])

# %% [markdown]
# # Calculations for VIX

# %%
# Calculating the returns for VIX
VIX['VIX_Returns'] = VIX['VIX'].pct_change()

# Calculating the MAs for VIX
VIX['VIX_21-day_MA'] = VIX['VIX'].rolling(21).mean()
VIX['VIX_55-day_MA'] = VIX['VIX'].rolling(55).mean()
VIX['VIX_100-day_MA'] = VIX['VIX'].rolling(100).mean()

# %%
VIX
# Out:
#            Date    VIX  VIX_Returns  VIX_21-day_MA  VIX_55-day_MA  \
# 0    1990-01-02  17.24          NaN            NaN            NaN
# 1    1990-01-03  18.19     0.055104            NaN            NaN
# 2    1990-01-04  19.22     0.056625            NaN            NaN
# 3    1990-01-05  20.11     0.046306            NaN            NaN
# 4    1990-01-08  20.26     0.007459            NaN            NaN
# ...         ...    ...          ...            ...            ...
# 7686 2020-07-06  27.94     0.009393      31.539524      32.104182
# 7687 2020-07-07  29.43     0.053329      31.773333      31.945636
# 7688 2020-07-08  28.08    -0.045872      31.881429      31.659273
# 7689 2020-07-09  29.26     0.042023      31.961905      31.365636
# 7690 2020-07-10  27.29    -0.067327      31.948571      31.098545
#
#       VIX_100-day_MA
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7686         37.9068
# 7687         38.0637
# 7688         38.2030
# 7689         38.3588
# 7690         38.4834
#
# [7691 rows x 6 columns]

# %% [markdown]
# ## USD/JPY

# %%
# Formatting the date
USDJPY['DATE'] = pd.to_datetime(USDJPY['DATE'])
USDJPY['DEXJPUS'] = pd.to_numeric(USDJPY['DEXJPUS'])

# %%
USDJPY
# Out:
#             DATE  DEXJPUS
# 0     1971-01-04   357.73
# 1     1971-01-05   357.81
# 2     1971-01-06   357.86
# 3     1971-01-07   357.87
# 4     1971-01-08   357.82
# ...          ...      ...
# 12414 2020-07-06   107.50
# 12415 2020-07-07   107.53
# 12416 2020-07-08   107.39
# 12417 2020-07-09   107.27
# 12418 2020-07-10   106.77
#
# [12419 rows x 2 columns]

# %% [markdown]
# ## USD/JPY Calculations

# %%
# Calculating the returns for VIX
USDJPY['USD/JPY_Returns'] = USDJPY['DEXJPUS'].pct_change()

#Calculating the MAs for VIX
USDJPY['USD_21-day_MA'] = USDJPY['DEXJPUS'].rolling(21).mean()
USDJPY['USD_55-day_MA'] = USDJPY['DEXJPUS'].rolling(55).mean()
USDJPY['USD_100-day_MA'] = USDJPY['DEXJPUS'].rolling(100).mean()

# %%
USDJPY
# Out:
#             DATE  DEXJPUS  USD/JPY_Returns  USD_21-day_MA  USD_55-day_MA  \
# 0     1971-01-04   357.73              NaN            NaN            NaN
# 1     1971-01-05   357.81         0.000224            NaN            NaN
# 2     1971-01-06   357.86         0.000140            NaN            NaN
# 3     1971-01-07   357.87         0.000028            NaN            NaN
# 4     1971-01-08   357.82        -0.000140            NaN            NaN
# ...          ...      ...              ...            ...            ...
# 12414 2020-07-06   107.50        -0.000465     107.391905     107.395091
# 12415 2020-07-07   107.53         0.000279     107.289524     107.395273
# 12416 2020-07-08   107.39        -0.001302     107.238571     107.389818
# 12417 2020-07-09   107.27        -0.001117     107.220000     107.382182
# 12418 2020-07-10   106.77        -0.004661     107.197143     107.363273
#
#        USD_100-day_MA
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 12414        107.8577
# 12415        107.8349
# 12416        107.8111
# 12417        107.7858
# 12418        107.7418
#
# [12419 rows x 6 columns]

# %% [markdown]
# ## Ted Spread

# %%
Ted_Spread['Date'] = pd.to_datetime(Ted_Spread['Date'])

# %%
# Calculating the returns for Ted Spread
Ted_Spread['Ted_Spread_Return'] = Ted_Spread['Value'].pct_change()

# %% [markdown]
# ## Credit Spreads

# %%
B_Spread
# Out:
#             DATE  BAMLH0A2HYBEY
# 0     1996-12-31          10.01
# 1     1997-01-02          10.00
# 2     1997-01-03          10.01
# 3     1997-01-06          10.05
# 4     1997-01-07          10.07
# ...          ...            ...
# 6138  2020-07-09           6.65
# 6139  2020-07-10           6.67
# 6140  2020-07-13           6.54
# 6141  2020-07-14           6.54
# 6142  2020-07-15           6.30
#
# [6143 rows x 2 columns]

# %%
Treasury_curve
# Out:
#             Date  1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# 0     1990-01-02   NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87  7.98   7.94
# 1     1990-01-03   NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92  8.04   7.99
# 2     1990-01-04   NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91  8.02   7.98
# 3     1990-01-05   NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92  8.03   7.99
# 4     1990-01-08   NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92  8.05   8.02
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 7636  2020-07-10  0.10  0.12  0.13  0.15  0.15  0.16  0.19  0.30  0.49   0.65
# 7637  2020-07-13  0.11  0.12  0.14  0.15  0.16  0.16  0.19  0.30  0.48   0.64
# 7638  2020-07-14  0.11  0.14  0.15  0.14  0.17  0.14  0.19  0.28  0.47   0.63
# 7639  2020-07-15  0.12  0.13  0.16  0.15  0.15  0.16  0.18  0.28  0.47   0.64
# 7640  2020-07-16  0.12  0.11  0.11  0.13  0.14  0.16  0.17  0.28  0.46   0.62
#
#       20 YR  30 YR
# 0       NaN   8.00
# 1       NaN   8.04
# 2       NaN   8.04
# 3       NaN   8.06
# 4       NaN   8.09
# ...     ...    ...
# 7636   1.12   1.33
# 7637   1.11   1.33
# 7638   1.09   1.30
# 7639   1.11   1.33
# 7640   1.09   1.31
#
# [7641 rows x 13 columns]

# %% [markdown]
# ## Nikkei Formatting

# %%
# Formatting date
Nikkei['Date'] = pd.to_datetime(Nikkei['Date'])

# Calculating Nikkei Returns
Nikkei['Nikkei_Returns'] = Nikkei['Value'].pct_change()

# Calculating Nikkei Historical Vol
Nikkei['Nikkei_20-day_Vol']= Nikkei['Nikkei_Returns'].rolling(20).std() * np.sqrt(252)*100 
Nikkei['Nikkei_50-day_Vol']= Nikkei['Nikkei_Returns'].rolling(50).std() * np.sqrt(252)*100 
Nikkei['Nikkei_100-day_Vol']= Nikkei['Nikkei_Returns'].rolling(100).std() * np.sqrt(252)*100 

# Calculating the MAs for Nikkei
Nikkei['Nikkei_21-day_MA'] = Nikkei['Value'].rolling(21).mean()
Nikkei['Nikkei_55-day_MA'] = Nikkei['Value'].rolling(55).mean()
Nikkei['Nikkei_100-day_MA'] = Nikkei['Value'].rolling(100).mean()

# %%
Nikkei
# Out:
#             Date     Value  Nikkei_Returns  Nikkei_20-day_Vol  \
# 0     1949-05-16    176.21             NaN                NaN
# 1     1949-05-17    174.80       -0.008002                NaN
# 2     1949-05-18    172.53       -0.012986                NaN
# 3     1949-05-19    171.34       -0.006897                NaN
# 4     1949-05-20    169.20       -0.012490                NaN
# ...          ...       ...             ...                ...
# 17685 2020-07-06  22714.44        0.018289          28.157875
# 17686 2020-07-07  22614.69       -0.004391          28.167434
# 17687 2020-07-08  22438.65       -0.007784          28.255891
# 17688 2020-07-09  22529.29        0.004039          26.453988
# 17689 2020-07-10  22290.81       -0.010585          26.598132
#
#        Nikkei_50-day_Vol  Nikkei_100-day_Vol  Nikkei_21-day_MA  \
# 0                    NaN                 NaN               NaN
# 1                    NaN                 NaN               NaN
# 2                    NaN                 NaN               NaN
# 3                    NaN                 NaN               NaN
# 4                    NaN                 NaN               NaN
# ...                  ...                 ...               ...
# 17685          24.287623           35.811029      22449.520952
# 17686          24.227973           35.816129      22422.691905
# 17687          24.203751           35.824676      22391.626190
# 17688          24.057720           35.810294      22363.261429
# 17689          23.622216           35.846988      22354.590000
#
#        Nikkei_55-day_MA  Nikkei_100-day_MA
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN
# 3                   NaN                NaN
# 4                   NaN                NaN
# ...                 ...                ...
# 17685      21255.360182         20796.0632
# 17686      21311.080182         20783.9303
# 17687      21368.324727         20771.4570
# 17688      21416.179818         20758.1378
# 17689      21463.846909         20742.7686
#
# [17690 rows x 9 columns]

# %% [markdown]
# ## Merging of the DataFrames

# %%
VIX
# Out:
#            Date    VIX  VIX_Returns  VIX_21-day_MA  VIX_55-day_MA  \
# 0    1990-01-02  17.24          NaN            NaN            NaN
# 1    1990-01-03  18.19     0.055104            NaN            NaN
# 2    1990-01-04  19.22     0.056625            NaN            NaN
# 3    1990-01-05  20.11     0.046306            NaN            NaN
# 4    1990-01-08  20.26     0.007459            NaN            NaN
# ...         ...    ...          ...            ...            ...
# 7686 2020-07-06  27.94     0.009393      31.539524      32.104182
# 7687 2020-07-07  29.43     0.053329      31.773333      31.945636
# 7688 2020-07-08  28.08    -0.045872      31.881429      31.659273
# 7689 2020-07-09  29.26     0.042023      31.961905      31.365636
# 7690 2020-07-10  27.29    -0.067327      31.948571      31.098545
#
#       VIX_100-day_MA
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7686         37.9068
# 7687         38.0637
# 7688         38.2030
# 7689         38.3588
# 7690         38.4834
#
# [7691 rows x 6 columns]

# %%
EM_Yields
# Out:
#            DATE  BAMLEMHBHYCRPIEY  EM Returns  EM_Bonds_20-day_Vol  \
# 0    1998-12-31             14.92         NaN                  NaN
# 1    1999-01-04             14.90   -0.001340                  NaN
# 2    1999-01-05             14.89   -0.000671                  NaN
# 3    1999-01-06             14.79   -0.006716                  NaN
# 4    1999-01-07             14.78   -0.000676                  NaN
# ...         ...               ...         ...                  ...
# 5619 2020-07-09              7.48    0.002681            13.489328
# 5620 2020-07-10              7.51    0.004011            13.639344
# 5621 2020-07-13              7.49   -0.002663            12.136466
# 5622 2020-07-14              7.52    0.004005            10.228824
# 5623 2020-07-15              7.47   -0.006649            10.299046
#
#       EM_Bonds_50-day_Vol  EM_Bonds_100-day_Vol  EM_Bonds_21-day_MA  \
# 0                     NaN                   NaN                 NaN
# 1                     NaN                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 3                     NaN                   NaN                 NaN
# 4                     NaN                   NaN                 NaN
# ...                   ...                   ...                 ...
# 5619            18.095147             48.200708            7.758571
# 5620            17.999389             48.135374            7.737619
# 5621            17.939409             48.140856            7.715238
# 5622            18.040676             48.047347            7.689048
# 5623            17.960005             47.830196            7.669048
#
#       EM_Bonds_55-day_MA  EM_Bonds_100-day_MA
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ...                  ...                  ...
# 5619            8.616000               9.1899
# 5620            8.561455               9.2041
# 5621            8.507818               9.2178
# 5622            8.457091               9.2305
# 5623            8.411455               9.2407
#
# [5624 rows x 9 columns]

# %%
SP500_Price
# Out:
#            Date  Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  \
# 0    1997-09-09         944.00           NaN         NaN         NaN
# 1    1997-09-10         925.00     -0.020127         NaN         NaN
# 2    1997-09-11         918.25     -0.007297         NaN         NaN
# 3    1997-09-12         933.75      0.016880         NaN         NaN
# 4    1997-09-15         931.50     -0.002410         NaN         NaN
# ...         ...            ...           ...         ...         ...
# 5810 2020-07-09        3130.50     -0.007057   27.936183   25.146713
# 5811 2020-07-10        3167.50      0.011819   19.276800   24.660182
# 5812 2020-07-13        3137.50     -0.009471   19.642138   24.560830
# 5813 2020-07-14        3172.75      0.011235   19.545827   23.688066
# 5814 2020-07-15        3208.50      0.011268   18.901618   23.767095
#
#       100-day_Vol    21-day_MA    55-day_MA  100-day_MA
# 0             NaN          NaN          NaN         NaN
# 1             NaN          NaN          NaN         NaN
# 2             NaN          NaN          NaN         NaN
# 3             NaN          NaN          NaN         NaN
# 4             NaN          NaN          NaN         NaN
# ...           ...          ...          ...         ...
# 5810    49.192179  3088.047619  2995.604545   2892.7000
# 5811    49.226894  3087.666667  3002.631818   2890.6775
# 5812    49.240854  3094.238095  3009.259091   2888.1725
# 5813    49.267736  3101.333333  3015.645455   2886.2025
# 5814    49.279935  3108.309524  3021.963636   2884.8925
#
# [5815 rows x 9 columns]

# %%
Nikkei
# Out:
#             Date     Value  Nikkei_Returns  Nikkei_20-day_Vol  \
# 0     1949-05-16    176.21             NaN                NaN
# 1     1949-05-17    174.80       -0.008002                NaN
# 2     1949-05-18    172.53       -0.012986                NaN
# 3     1949-05-19    171.34       -0.006897                NaN
# 4     1949-05-20    169.20       -0.012490                NaN
# ...          ...       ...             ...                ...
# 17685 2020-07-06  22714.44        0.018289          28.157875
# 17686 2020-07-07  22614.69       -0.004391          28.167434
# 17687 2020-07-08  22438.65       -0.007784          28.255891
# 17688 2020-07-09  22529.29        0.004039          26.453988
# 17689 2020-07-10  22290.81       -0.010585          26.598132
#
#        Nikkei_50-day_Vol  Nikkei_100-day_Vol  Nikkei_21-day_MA  \
# 0                    NaN                 NaN               NaN
# 1                    NaN                 NaN               NaN
# 2                    NaN                 NaN               NaN
# 3                    NaN                 NaN               NaN
# 4                    NaN                 NaN               NaN
# ...                  ...                 ...               ...
# 17685          24.287623           35.811029      22449.520952
# 17686          24.227973           35.816129      22422.691905
# 17687          24.203751           35.824676      22391.626190
# 17688          24.057720           35.810294      22363.261429
# 17689          23.622216           35.846988      22354.590000
#
#        Nikkei_55-day_MA  Nikkei_100-day_MA
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN
# 3                   NaN                NaN
# 4                   NaN                NaN
# ...                 ...                ...
# 17685      21255.360182         20796.0632
# 17686      21311.080182         20783.9303
# 17687      21368.324727         20771.4570
# 17688      21416.179818         20758.1378
# 17689      21463.846909         20742.7686
#
# [17690 rows x 9 columns]

# %% [markdown]
# ## Merging SP500 and Nikkei

# %%
SP500 = SP500_Price.loc[(SP500_Price['Date']>='1997-09-09') & (SP500_Price['Date']<='2020-07-10')]
Nikkei = Nikkei.loc[(Nikkei['Date']>='1997-09-09') & (Nikkei['Date']<='2020-07-10')]

# %%
SP500
# Out:
#            Date  Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  \
# 0    1997-09-09         944.00           NaN         NaN         NaN
# 1    1997-09-10         925.00     -0.020127         NaN         NaN
# 2    1997-09-11         918.25     -0.007297         NaN         NaN
# 3    1997-09-12         933.75      0.016880         NaN         NaN
# 4    1997-09-15         931.50     -0.002410         NaN         NaN
# ...         ...            ...           ...         ...         ...
# 5807 2020-07-06        3161.50      0.013789   27.938213   25.211260
# 5808 2020-07-07        3126.00     -0.011229   27.778318   25.172134
# 5809 2020-07-08        3152.75      0.008557   27.904731   25.070111
# 5810 2020-07-09        3130.50     -0.007057   27.936183   25.146713
# 5811 2020-07-10        3167.50      0.011819   19.276800   24.660182
#
#       100-day_Vol    21-day_MA    55-day_MA  100-day_MA
# 0             NaN          NaN          NaN         NaN
# 1             NaN          NaN          NaN         NaN
# 2             NaN          NaN          NaN         NaN
# 3             NaN          NaN          NaN         NaN
# 4             NaN          NaN          NaN         NaN
# ...           ...          ...          ...         ...
# 5807    49.142398  3096.547619  2977.018182   2900.0125
# 5808    49.160609  3094.142857  2981.809091   2897.4625
# 5809    49.180624  3091.095238  2988.231818   2895.2100
# 5810    49.192179  3088.047619  2995.604545   2892.7000
# 5811    49.226894  3087.666667  3002.631818   2890.6775
#
# [5812 rows x 9 columns]

# %%
Merged_SP500_Nikkei = pd.merge_asof(SP500,Nikkei,on='Date')

# %%
# Dropping N/A
Merged_SP500_Nikkei.dropna()
# Out:
#            Date  Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  \
# 100  1998-01-30         995.25     -0.004252   19.745629   17.906344
# 101  1998-02-02        1016.50      0.021351   21.057299   18.455638
# 102  1998-02-03        1020.50      0.003935   21.074817   18.159598
# 103  1998-02-04        1021.00      0.000490   20.312998   18.109067
# 104  1998-02-05        1016.75     -0.004163   20.428176   17.483172
# ...         ...            ...           ...         ...         ...
# 5807 2020-07-06        3161.50      0.013789   27.938213   25.211260
# 5808 2020-07-07        3126.00     -0.011229   27.778318   25.172134
# 5809 2020-07-08        3152.75      0.008557   27.904731   25.070111
# 5810 2020-07-09        3130.50     -0.007057   27.936183   25.146713
# 5811 2020-07-10        3167.50      0.011819   19.276800   24.660182
#
#       100-day_Vol    21-day_MA    55-day_MA  100-day_MA     Value  \
# 100     23.453145   979.678571   973.009091    967.1825  16628.47
# 101     23.442655   981.011905   974.804545    968.0975  16776.82
# 102     23.408605   982.297619   976.468182    969.1200  17022.98
# 103     23.272723   983.488095   977.895455    969.9925  16882.62
# 104     23.280924   985.130952   978.927273    970.8450  17003.30
# ...           ...          ...          ...         ...       ...
# 5807    49.142398  3096.547619  2977.018182   2900.0125  22714.44
# 5808    49.160609  3094.142857  2981.809091   2897.4625  22614.69
# 5809    49.180624  3091.095238  2988.231818   2895.2100  22438.65
# 5810    49.192179  3088.047619  2995.604545   2892.7000  22529.29
# 5811    49.226894  3087.666667  3002.631818   2890.6775  22290.81
#
#       Nikkei_Returns  Nikkei_20-day_Vol  Nikkei_50-day_Vol  \
# 100        -0.022693          32.470149          42.669541
# 101         0.008921          30.947085          42.333627
# 102         0.014673          29.688523          38.593246
# 103        -0.008245          29.925966          38.181613
# 104         0.007148          29.913960          36.196360
# ...              ...                ...                ...
# 5807        0.018289          28.157875          24.287623
# 5808       -0.004391          28.167434          24.227973
# 5809       -0.007784          28.255891          24.203751
# 5810        0.004039          26.453988          24.057720
# 5811       -0.010585          26.598132          23.622216
#
#       Nikkei_100-day_Vol  Nikkei_21-day_MA  Nikkei_55-day_MA  \
# 100            35.529922      15842.766190      15950.952364
# 101            35.497404      15938.080476      15968.051636
# 102            35.500692      16022.091905      15992.156727
# 103            35.235714      16113.795714      16010.618364
# 104            35.246471      16214.124286      16039.148000
# ...                  ...               ...               ...
# 5807           35.811029      22449.520952      21255.360182
# 5808           35.816129      22422.691905      21311.080182
# 5809           35.824676      22391.626190      21368.324727
# 5810           35.810294      22363.261429      21416.179818
# 5811           35.846988      22354.590000      21463.846909
#
#       Nikkei_100-day_MA
# 100          16717.9787
# 101          16706.0039
# 102          16693.9085
# 103          16675.3830
# 104          16659.2654
# ...                 ...
# 5807         20796.0632
# 5808         20783.9303
# 5809         20771.4570
# 5810         20758.1378
# 5811         20742.7686
#
# [5712 rows x 17 columns]

# %% [markdown]
# ## Linear Regression SP500 vs Nikkei

# %% [markdown]
# ## Training Data Set

# %%
# Separating Training sets and Testing sets
SP_Nikkei_Training = Merged_SP500_Nikkei.loc[(Merged_SP500_Nikkei['Date']>='1998-01-30') & (Merged_SP500_Nikkei['Date']<='2017-01-01')]

# Dropping the date 
SP_Nikkei_Training = SP_Nikkei_Training.drop(columns=['Date'])

# %%
SP_Nikkei_Training
# Out:
#       Closing_Price  Daily_Return  20-day_Vol  50-day_Vol  100-day_Vol  \
# 100          995.25     -0.004252   19.745629   17.906344    23.453145
# 101         1016.50      0.021351   21.057299   18.455638    23.442655
# 102         1020.50      0.003935   21.074817   18.159598    23.408605
# 103         1021.00      0.000490   20.312998   18.109067    23.272723
# 104         1016.75     -0.004163   20.428176   17.483172    23.280924
# ...             ...           ...         ...         ...          ...
# 4920        2254.50      0.000555    7.217255    8.616126     9.667996
# 4921        2255.50      0.000444    6.886514    8.615675     9.667594
# 4922        2239.75     -0.006983    7.495085    8.785113     9.661176
# 4923        2239.50     -0.000112    7.411134    8.760184     9.660338
# 4924        2230.50     -0.004019    7.487719    8.823448     9.684398
#
#         21-day_MA    55-day_MA  100-day_MA     Value  Nikkei_Returns  \
# 100    979.678571   973.009091    967.1825  16628.47       -0.022693
# 101    981.011905   974.804545    968.0975  16776.82        0.008921
# 102    982.297619   976.468182    969.1200  17022.98        0.014673
# 103    983.488095   977.895455    969.9925  16882.62       -0.008245
# 104    985.130952   978.927273    970.8450  17003.30        0.007148
# ...           ...          ...         ...       ...             ...
# 4920  2231.595238  2173.445455   2166.0175  19427.67       -0.000865
# 4921  2233.940476  2175.527273   2167.0550  19403.06        0.000331
# 4922  2236.035714  2177.095455   2167.7600  19401.72       -0.000069
# 4923  2237.976190  2179.104545   2168.4750  19145.14       -0.013225
# 4924  2239.726190  2181.004545   2169.0775  19114.37       -0.001607
#
#       Nikkei_20-day_Vol  Nikkei_50-day_Vol  Nikkei_100-day_Vol  \
# 100           32.470149          42.669541           35.529922
# 101           30.947085          42.333627           35.497404
# 102           29.688523          38.593246           35.500692
# 103           29.925966          38.181613           35.235714
# 104           29.913960          36.196360           35.246471
# ...                 ...                ...                 ...
# 4920           9.457144          22.364483           19.574585
# 4921           9.517783          22.124090           19.463461
# 4922           9.359707          22.130406           19.461654
# 4923          10.951971          22.425040           19.431850
# 4924          10.502202          22.443071           19.161270
#
#       Nikkei_21-day_MA  Nikkei_55-day_MA  Nikkei_100-day_MA
# 100       15842.766190      15950.952364         16717.9787
# 101       15938.080476      15968.051636         16706.0039
# 102       16022.091905      15992.156727         16693.9085
# 103       16113.795714      16010.618364         16675.3830
# 104       16214.124286      16039.148000         16659.2654
# ...                ...               ...                ...
# 4920      18838.699524      17854.690727         17312.8715
# 4921      18937.988571      17950.050909         17370.4074
# 4922      18987.742381      17995.553091         17398.0669
# 4923      19027.651905      18037.099455         17425.6038
# 4924      19066.027619      18075.092364         17455.9164
#
# [4825 rows x 16 columns]

# %% [markdown]
# ## Testing Data Set

# %%
# Separating Training sets and Testing sets
SP_Nikkei_Testing = Merged_SP500_Nikkei.loc[(Merged_SP500_Nikkei['Date']>='2017-01-02') & (Merged_SP500_Nikkei['Date']<='2020-07-10')]

# Dropping the date 
SP_Nikkei_Testing = SP_Nikkei_Testing.drop(columns=['Date'])

# %% [markdown]
# ## Machine Learning - Training Data Set

# %%
X_train = SP_Nikkei_Training[['Daily_Return',
                             '20-day_Vol',
                             '50-day_Vol',
                             '100-day_Vol',
                             'Nikkei_20-day_Vol',
                             'Nikkei_50-day_Vol',
                             'Nikkei_100-day_Vol']]

y_train = SP_Nikkei_Training[['Nikkei_Returns']].values.reshape(-1,1)

# %%
y_train
# Out:
# array([[-2.26934648e-02],
#        [ 8.92144617e-03],
#        [ 1.46726257e-02],
#        ...,
#        [-6.90612718e-05],
#        [-1.32246007e-02],
#        [-1.60719640e-03]])

# %% [markdown]
# ## Testing Data - y_train

# %%
X_test = SP_Nikkei_Testing[['Daily_Return',
                             '20-day_Vol',
                             '50-day_Vol',
                             '100-day_Vol',
                             'Nikkei_20-day_Vol',
                             'Nikkei_50-day_Vol',
                             'Nikkei_100-day_Vol']]

y_test = SP_Nikkei_Testing[['Nikkei_Returns']].values.reshape(-1,1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4825, 7) (4825, 1)
# (887, 7) (887, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.017755882758254238
# Testing Score: 0.06212574193380893

# %% [markdown]
# ## Scatter Plot SP500 Returns vs Nikkei Returns

# %%
plt.scatter(SP_Nikkei_Training['Daily_Return'],SP_Nikkei_Training['Nikkei_Returns'])
