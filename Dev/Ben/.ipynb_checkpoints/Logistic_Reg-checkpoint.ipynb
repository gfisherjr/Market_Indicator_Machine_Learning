# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import scipy.stats as sts
# import quandl
import os
import numpy as np
from scipy import stats
from scipy.stats import linregress
from scipy.stats import pearsonr


import quandl
from config import api_key

# %% [markdown]
# ## SP500

# %%
SP500 = pd.read_csv('SP500.csv')

# %%
del SP500['Change']
del SP500['High']
del SP500['Low']
del SP500['Settle']
del SP500['Volume']
del SP500['Previous Day Open Interest']

# %%
SP500.rename(columns={'Last':'Close'}, inplace=True)

# %%
SP500
# Out:
#             Date     Open    Close
# 0     1997-09-09   943.50   944.00
# 1     1997-09-10   942.75   925.00
# 2     1997-09-11   924.00   918.25
# 3     1997-09-12   918.00   933.75
# 4     1997-09-15   933.50   931.50
# ...          ...      ...      ...
# 5815  2020-07-16  3212.50  3185.75
# 5816  2020-07-17  3185.00  3203.50
# 5817  2020-07-20  3204.75  3233.25
# 5818  2020-07-21  3235.50  3239.00
# 5819  2020-07-22  3239.75  3256.00
#
# [5820 rows x 3 columns]

# %%
SP500['10day_MA'] = SP500['Close'].rolling(window=10).mean()
SP500['Log_Returns'] = np.log(SP500['Close']/SP500['Close'].shift(1))

# 10day Annualized Vol
SP500['10day_Vol'] = SP500['Log_Returns'].rolling(10).std() * np.sqrt(252) * 100

# Correlation between SP500 Close and 10 day Moving Average
SP500['10day_Correl'] = SP500['Close'].rolling(10).corr(SP500['10day_MA'])

SP500['Open-Close'] = SP500['Open'] - SP500['Close'].shift(1)
SP500['Open-Open'] = SP500['Open'] - SP500['Open'].shift(1)

# %%
SP500 = SP500.dropna()

# %%
del SP500['Log_Returns']

# %%
SP500 = SP500.set_index('Date')

# %%
UST_Curve = pd.read_csv('UST_Curve.csv')
Ten_Year = pd.DataFrame({'Date':UST_Curve['Date'],
                        '10Year': UST_Curve['10 YR']
                        })

# %%
Ten_Year = Ten_Year.loc[Ten_Year['Date']>='1997-10-03']

# %%
Ten_Year = Ten_Year.set_index('Date')

# %%
SP500
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2020-07-16  3212.50  3185.75  3156.100  16.542544      0.792862        1.50
# 2020-07-17  3185.00  3203.50  3164.925  16.377104      0.799482       -0.75
# 2020-07-20  3204.75  3233.25  3172.375  15.650139      0.884427        1.25
# 2020-07-21  3235.50  3239.00  3183.775  13.884162      0.889330        2.25
# 2020-07-22  3239.75  3256.00  3193.925  13.549490      0.932409        0.75
#
#             Open-Open
# Date
# 1997-10-03      25.25
# 1997-10-06      -6.75
# 1997-10-07       4.25
# 1997-10-08      -3.50
# 1997-10-09      -1.00
# ...               ...
# 2020-07-16      13.50
# 2020-07-17     -27.50
# 2020-07-20      19.75
# 2020-07-21      30.75
# 2020-07-22       4.25
#
# [5802 rows x 7 columns]

# %%
Ten_Year
# Out:
#             10Year
# Date
# 1997-10-03    6.01
# 1997-10-06    5.96
# 1997-10-07    5.94
# 1997-10-08    6.08
# 1997-10-09    6.09
# ...            ...
# 2020-07-08    0.67
# 2020-07-09    0.62
# 2020-07-10    0.65
# 2020-07-13    0.64
# 2020-07-14    0.63
#
# [5697 rows x 1 columns]

# %%
log_df = pd.merge(SP500,Ten_Year,on=['Date'])

# %%
log_df
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943       -0.25
# 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166        4.00
# 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613        6.25
# 2020-07-13  3171.75  3137.75  3119.200  15.959411      0.587884        3.50
# 2020-07-14  3144.00  3173.00  3132.900  15.481814      0.701805        6.25
#
#             Open-Open  10Year
# Date
# 1997-10-03      25.25    6.01
# 1997-10-06      -6.75    5.96
# 1997-10-07       4.25    5.94
# 1997-10-08      -3.50    6.08
# 1997-10-09      -1.00    6.09
# ...               ...     ...
# 2020-07-08     -33.50    0.67
# 2020-07-09      33.75    0.62
# 2020-07-10     -20.50    0.65
# 2020-07-13      33.75    0.64
# 2020-07-14     -27.75    0.63
#
# [5693 rows x 8 columns]

# %%
Nikkei = pd.read_csv('Nikkei.csv')
Nikkei['Date'] = pd.to_datetime(Nikkei['Date'])
Nikkei = Nikkei.loc[Nikkei['Date']>='1997-10-03']

# %%
Nikkei = Nikkei.set_index('Date')

# %%
Nikkei.rename(columns={'Value':'Nikkei'}, inplace=True)

# %%
Nikkei = Nikkei.reset_index()

# %%
log_df = log_df.reset_index()

# %%
log_df
# Out:
#             Date     Open    Close  10day_MA  10day_Vol  10day_Correl  \
# 0     1997-10-03   996.00   986.00   971.000  11.941077      0.330571
# 1     1997-10-06   989.25   989.00   972.225  11.732145      0.674904
# 2     1997-10-07   993.50  1000.00   975.000  12.169754      0.889650
# 3     1997-10-08   990.00   992.75   977.800  12.057922      0.950888
# 4     1997-10-09   989.00   988.50   980.975  11.144922      0.863067
# ...          ...      ...      ...       ...        ...           ...
# 5688  2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943
# 5689  2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166
# 5690  2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613
# 5691  2020-07-13  3171.75  3137.75  3119.200  15.959411      0.587884
# 5692  2020-07-14  3144.00  3173.00  3132.900  15.481814      0.701805
#
#       Open-Close  Open-Open  10Year
# 0          16.50      25.25    6.01
# 1           3.25      -6.75    5.96
# 2           4.50       4.25    5.94
# 3         -10.00      -3.50    6.08
# 4          -3.75      -1.00    6.09
# ...          ...        ...     ...
# 5688       -0.25     -33.50    0.67
# 5689        4.00      33.75    0.62
# 5690        6.25     -20.50    0.65
# 5691        3.50      33.75    0.64
# 5692        6.25     -27.75    0.63
#
# [5693 rows x 9 columns]

# %%
VIX = pd.read_csv('VIX.csv')
VIX['Date'] = pd.to_datetime(VIX['Date'])
VIX = VIX.loc[VIX['Date']>='1997-10-03']

# %%
VIX
# Out:
#            Date    VIX
# 1961 1997-10-03  21.54
# 1962 1997-10-06  21.61
# 1963 1997-10-07  20.29
# 1964 1997-10-08  20.77
# 1965 1997-10-09  22.31
# ...         ...    ...
# 7686 2020-07-06  27.94
# 7687 2020-07-07  29.43
# 7688 2020-07-08  28.08
# 7689 2020-07-09  29.26
# 7690 2020-07-10  27.29
#
# [5730 rows x 2 columns]

# %%
log_df['Date'] = pd.to_datetime(log_df['Date'])

# %%
log_df = pd.merge(log_df,VIX,on=['Date'])

# %%
log_df = pd.merge(log_df,Nikkei,on=['Date'])

# %%
log_df
# Out:
#            Date     Open    Close  10day_MA  10day_Vol  10day_Correl  \
# 0    1997-10-03   996.00   986.00   971.000  11.941077      0.330571
# 1    1997-10-06   989.25   989.00   972.225  11.732145      0.674904
# 2    1997-10-07   993.50  1000.00   975.000  12.169754      0.889650
# 3    1997-10-08   990.00   992.75   977.800  12.057922      0.950888
# 4    1997-10-09   989.00   988.50   980.975  11.144922      0.863067
# ...         ...      ...      ...       ...        ...           ...
# 5368 2020-07-06  3115.25  3158.75  3077.425  22.223635      0.211815
# 5369 2020-07-07  3158.25  3125.00  3079.825  22.335389      0.219537
# 5370 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943
# 5371 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166
# 5372 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613
#
#       Open-Close  Open-Open  10Year    VIX    Nikkei
# 0          16.50      25.25    6.01  21.54  17647.45
# 1           3.25      -6.75    5.96  21.61  17824.78
# 2           4.50       4.25    5.94  20.29  17511.19
# 3         -10.00      -3.50    6.08  20.77  17619.18
# 4          -3.75      -1.00    6.09  22.31  17376.92
# ...          ...        ...     ...    ...       ...
# 5368        0.00      23.00    0.69  27.94  22714.44
# 5369       -0.50      43.00    0.65  29.43  22614.69
# 5370       -0.25     -33.50    0.67  28.08  22438.65
# 5371        4.00      33.75    0.62  29.26  22529.29
# 5372        6.25     -20.50    0.65  27.29  22290.81
#
# [5373 rows x 11 columns]

# %% [markdown]
# ## USDJPY

# %%
USDJPY = pd.read_csv('USDJPY.csv')
USDJPY.rename(columns={'DATE':'Date'}, inplace=True)
USDJPY.rename(columns={'DEXJPUS':'USDJPY'}, inplace=True)
USDJPY['Date'] = pd.to_datetime(USDJPY['Date'])
USDJPY = USDJPY.loc[USDJPY['Date']>='1997-10-03']

# %%
USDJPY
# Out:
#             Date  USDJPY
# 6703  1997-10-03  121.93
# 6704  1997-10-06  121.93
# 6705  1997-10-07  122.01
# 6706  1997-10-08  121.09
# 6707  1997-10-09  121.18
# ...          ...     ...
# 12414 2020-07-06  107.50
# 12415 2020-07-07  107.53
# 12416 2020-07-08  107.39
# 12417 2020-07-09  107.27
# 12418 2020-07-10  106.77
#
# [5716 rows x 2 columns]

# %%
log_df = pd.merge(log_df,USDJPY,on=['Date'])

# %%
log_df
# Out:
#            Date     Open    Close  10day_MA  10day_Vol  10day_Correl  \
# 0    1997-10-03   996.00   986.00   971.000  11.941077      0.330571
# 1    1997-10-06   989.25   989.00   972.225  11.732145      0.674904
# 2    1997-10-07   993.50  1000.00   975.000  12.169754      0.889650
# 3    1997-10-08   990.00   992.75   977.800  12.057922      0.950888
# 4    1997-10-09   989.00   988.50   980.975  11.144922      0.863067
# ...         ...      ...      ...       ...        ...           ...
# 5364 2020-07-06  3115.25  3158.75  3077.425  22.223635      0.211815
# 5365 2020-07-07  3158.25  3125.00  3079.825  22.335389      0.219537
# 5366 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943
# 5367 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166
# 5368 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613
#
#       Open-Close  Open-Open  10Year    VIX    Nikkei  USDJPY
# 0          16.50      25.25    6.01  21.54  17647.45  121.93
# 1           3.25      -6.75    5.96  21.61  17824.78  121.93
# 2           4.50       4.25    5.94  20.29  17511.19  122.01
# 3         -10.00      -3.50    6.08  20.77  17619.18  121.09
# 4          -3.75      -1.00    6.09  22.31  17376.92  121.18
# ...          ...        ...     ...    ...       ...     ...
# 5364        0.00      23.00    0.69  27.94  22714.44  107.50
# 5365       -0.50      43.00    0.65  29.43  22614.69  107.53
# 5366       -0.25     -33.50    0.67  28.08  22438.65  107.39
# 5367        4.00      33.75    0.62  29.26  22529.29  107.27
# 5368        6.25     -20.50    0.65  27.29  22290.81  106.77
#
# [5369 rows x 12 columns]

# %%
log_df.set_index('Date', inplace=True)

# %%
log_df
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2020-07-06  3115.25  3158.75  3077.425  22.223635      0.211815        0.00
# 2020-07-07  3158.25  3125.00  3079.825  22.335389      0.219537       -0.50
# 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943       -0.25
# 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166        4.00
# 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613        6.25
#
#             Open-Open  10Year    VIX    Nikkei  USDJPY
# Date
# 1997-10-03      25.25    6.01  21.54  17647.45  121.93
# 1997-10-06      -6.75    5.96  21.61  17824.78  121.93
# 1997-10-07       4.25    5.94  20.29  17511.19  122.01
# 1997-10-08      -3.50    6.08  20.77  17619.18  121.09
# 1997-10-09      -1.00    6.09  22.31  17376.92  121.18
# ...               ...     ...    ...       ...     ...
# 2020-07-06      23.00    0.69  27.94  22714.44  107.50
# 2020-07-07      43.00    0.65  29.43  22614.69  107.53
# 2020-07-08     -33.50    0.67  28.08  22438.65  107.39
# 2020-07-09      33.75    0.62  29.26  22529.29  107.27
# 2020-07-10     -20.50    0.65  27.29  22290.81  106.77
#
# [5369 rows x 11 columns]

# %%
log_df.corr()
# Out:
#                   Open     Close  10day_MA  10day_Vol  10day_Correl  \
# Open          1.000000  0.999496  0.999003  -0.230897      0.061189
# Close         0.999496  1.000000  0.998716  -0.230955      0.061277
# 10day_MA      0.999003  0.998716  1.000000  -0.222500      0.061766
# 10day_Vol    -0.230897 -0.230955 -0.222500   1.000000     -0.109379
# 10day_Correl  0.061189  0.061277  0.061766  -0.109379      1.000000
# Open-Close   -0.024790 -0.025627 -0.034336  -0.023328     -0.009819
# Open-Open     0.039119  0.034794  0.013973  -0.032648     -0.009248
# 10Year       -0.564750 -0.564889 -0.564614   0.069143     -0.081493
# VIX          -0.362202 -0.365964 -0.351278   0.857359     -0.038675
# Nikkei        0.837496  0.837259  0.836536  -0.228481      0.012025
# USDJPY        0.054146  0.054062  0.054966  -0.023194     -0.014027
#
#               Open-Close  Open-Open    10Year       VIX    Nikkei    USDJPY
# Open           -0.024790   0.039119 -0.564750 -0.362202  0.837496  0.054146
# Close          -0.025627   0.034794 -0.564889 -0.365964  0.837259  0.054062
# 10day_MA       -0.034336   0.013973 -0.564614 -0.351278  0.836536  0.054966
# 10day_Vol      -0.023328  -0.032648  0.069143  0.857359 -0.228481 -0.023194
# 10day_Correl   -0.009819  -0.009248 -0.081493 -0.038675  0.012025 -0.014027
# Open-Close      1.000000   0.304029  0.024497 -0.053830 -0.021736 -0.013042
# Open-Open       0.304029   1.000000 -0.020278 -0.108623  0.028147 -0.006134
# 10Year          0.024497  -0.020278  1.000000  0.112054 -0.116193  0.472690
# VIX            -0.053830  -0.108623  0.112054  1.000000 -0.361258 -0.055421
# Nikkei         -0.021736   0.028147 -0.116193 -0.361258  1.000000  0.405202
# USDJPY         -0.013042  -0.006134  0.472690 -0.055421  0.405202  1.000000

# %% [markdown]
# ## Logistic Regression Model

# %%
y = np.where(log_df['Nikkei'].shift(-1) > log_df['Nikkei'],1,-1)
y
# Out:
# array([ 1, -1,  1, ...,  1, -1, -1])

# %%
X = log_df.iloc[:,:11]
X
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2020-07-06  3115.25  3158.75  3077.425  22.223635      0.211815        0.00
# 2020-07-07  3158.25  3125.00  3079.825  22.335389      0.219537       -0.50
# 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943       -0.25
# 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166        4.00
# 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613        6.25
#
#             Open-Open  10Year    VIX    Nikkei  USDJPY
# Date
# 1997-10-03      25.25    6.01  21.54  17647.45  121.93
# 1997-10-06      -6.75    5.96  21.61  17824.78  121.93
# 1997-10-07       4.25    5.94  20.29  17511.19  122.01
# 1997-10-08      -3.50    6.08  20.77  17619.18  121.09
# 1997-10-09      -1.00    6.09  22.31  17376.92  121.18
# ...               ...     ...    ...       ...     ...
# 2020-07-06      23.00    0.69  27.94  22714.44  107.50
# 2020-07-07      43.00    0.65  29.43  22614.69  107.53
# 2020-07-08     -33.50    0.67  28.08  22438.65  107.39
# 2020-07-09      33.75    0.62  29.26  22529.29  107.27
# 2020-07-10     -20.50    0.65  27.29  22290.81  106.77
#
# [5369 rows x 11 columns]

# %% [markdown]
# ## Splitting the Training/Testing Data Sets

# %%
split = int(0.7*len(log_df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
X_train
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2013-08-21  1644.50  1629.75  1661.350   9.555786      0.892064        0.50
# 2013-08-22  1628.00  1648.00  1657.425  11.625780      0.810886       -1.75
# 2013-08-23  1648.50  1654.75  1654.925  11.978997      0.680984        0.50
# 2013-08-26  1654.25  1647.50  1651.600  11.996361      0.582136       -0.50
# 2013-08-27  1648.50  1621.50  1645.300  13.559916      0.588474        1.00
#
#             Open-Open  10Year    VIX    Nikkei  USDJPY
# Date
# 1997-10-03      25.25    6.01  21.54  17647.45  121.93
# 1997-10-06      -6.75    5.96  21.61  17824.78  121.93
# 1997-10-07       4.25    5.94  20.29  17511.19  122.01
# 1997-10-08      -3.50    6.08  20.77  17619.18  121.09
# 1997-10-09      -1.00    6.09  22.31  17376.92  121.18
# ...               ...     ...    ...       ...     ...
# 2013-08-21       7.00    2.87  15.94  13424.33   97.66
# 2013-08-22     -16.50    2.90  14.76  13365.17   98.53
# 2013-08-23      20.50    2.82  13.98  13660.55   98.57
# 2013-08-26       5.75    2.79  14.99  13636.28   98.64
# 2013-08-27      -5.75    2.72  16.77  13542.37   97.30
#
# [3758 rows x 11 columns]

# %%
y_train
# Out:
# array([ 1, -1,  1, ..., -1, -1, -1])

# %% [markdown]
# ## Train / Fit the model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
model = LogisticRegression()
model = model.fit (X_train,y_train)
pd.DataFrame(zip(X.columns, np.transpose(model.coef_)))
# Out:
#                0                         1
# 0           Open    [-0.05761415792035391]
# 1          Close    [0.058406625292633255]
# 2       10day_MA  [-0.0005340807152112852]
# 3      10day_Vol  [-0.0033976358148913406]
# 4   10day_Correl   [0.0011326955234739382]
# 5     Open-Close    [0.022512504724561982]
# 6      Open-Open    [0.000336581095323461]
# 7         10Year   [9.797996453868005e-05]
# 8            VIX   [-0.005661749892550257]
# 9         Nikkei  [-4.179577925559349e-05]
# 10        USDJPY   [0.0037405644591285247]

# %% [markdown]
# ## Model Validation

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6346460883448642
# Testing Data Score: 0.6517690875232774

# %% [markdown]
# ## Making Predictions

# %%
predictions = model.predict(X_test)
print(f"First 7 Predictions:   {predictions[:7]}")
print(f"First 7 Actual labels: {y_test[:7].tolist()}")
# Out:
# First 7 Predictions:   [ 1  1 -1  1  1  1  1]
# First 7 Actual labels: [1, -1, 1, 1, 1, -1, 1]

# %% [markdown]
# ## DataFrame for the predictions

# %%
Predictions_df = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)

# %%
Predictions_df
# Out:
#       Prediction  Actual
# 0              1       1
# 1              1      -1
# 2             -1       1
# 3              1       1
# 4              1       1
# ...          ...     ...
# 1606           1      -1
# 1607          -1      -1
# 1608           1       1
# 1609          -1      -1
# 1610           1      -1
#
# [1611 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, predictions)
# Out:
# 0.6517690875232774

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.66      0.52      0.58       754
#            1       0.65      0.76      0.70       857
#
#     accuracy                           0.65      1611
#    macro avg       0.65      0.64      0.64      1611
# weighted avg       0.65      0.65      0.65      1611

# %% [markdown]
# ## Getting the Confusion Matrix

# %%
cf_matrix = confusion_matrix(y_test,predictions)
print(cf_matrix)
# Out:
# [[395 359]
#  [202 655]]

# %%
import seaborn as sns
cf_matrix = confusion_matrix(y_test,predictions)

fig = plt.figure(figsize=(15, 5))
ax = sns.heatmap(cf_matrix, annot=True,fmt='g', linewidth=0.7, cmap='Blues', yticklabels=["-1","1"],xticklabels=["-1","1"] )
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top

plt.ylim(b, t) # update the ylim(bottom, top) values
ax.xaxis.set_label_position("top")
#fig.tight_layout()
plt.show()

# %%
log_df
# Out:
#                Open    Close  10day_MA  10day_Vol  10day_Correl  Open-Close  \
# Date
# 1997-10-03   996.00   986.00   971.000  11.941077      0.330571       16.50
# 1997-10-06   989.25   989.00   972.225  11.732145      0.674904        3.25
# 1997-10-07   993.50  1000.00   975.000  12.169754      0.889650        4.50
# 1997-10-08   990.00   992.75   977.800  12.057922      0.950888      -10.00
# 1997-10-09   989.00   988.50   980.975  11.144922      0.863067       -3.75
# ...             ...      ...       ...        ...           ...         ...
# 2020-07-06  3115.25  3158.75  3077.425  22.223635      0.211815        0.00
# 2020-07-07  3158.25  3125.00  3079.825  22.335389      0.219537       -0.50
# 2020-07-08  3124.75  3154.50  3085.000  22.748669      0.389943       -0.25
# 2020-07-09  3158.50  3131.75  3094.175  19.954788      0.429166        4.00
# 2020-07-10  3138.00  3168.25  3104.675  20.309758      0.571613        6.25
#
#             Open-Open  10Year    VIX    Nikkei  USDJPY
# Date
# 1997-10-03      25.25    6.01  21.54  17647.45  121.93
# 1997-10-06      -6.75    5.96  21.61  17824.78  121.93
# 1997-10-07       4.25    5.94  20.29  17511.19  122.01
# 1997-10-08      -3.50    6.08  20.77  17619.18  121.09
# 1997-10-09      -1.00    6.09  22.31  17376.92  121.18
# ...               ...     ...    ...       ...     ...
# 2020-07-06      23.00    0.69  27.94  22714.44  107.50
# 2020-07-07      43.00    0.65  29.43  22614.69  107.53
# 2020-07-08     -33.50    0.67  28.08  22438.65  107.39
# 2020-07-09      33.75    0.62  29.26  22529.29  107.27
# 2020-07-10     -20.50    0.65  27.29  22290.81  106.77
#
# [5369 rows x 11 columns]

# %%
Nikkei_SP500 = pd.DataFrame({'SP500':log_df['Close'],
                             'Nikkei': log_df['Nikkei']})

fig = plt.figure(figsize = (15,5))
plt.scatter(log_df['Close'],log_df['Nikkei'])
plt.title('Relationship between SP500 and Nikkei Indices')
plt.xlabel('SP500')
plt.ylabel('Nikkei')
plt.show()

# %%
Nikkei_SP500
# Out:
#               SP500    Nikkei
# Date
# 1997-10-03   986.00  17647.45
# 1997-10-06   989.00  17824.78
# 1997-10-07  1000.00  17511.19
# 1997-10-08   992.75  17619.18
# 1997-10-09   988.50  17376.92
# ...             ...       ...
# 2020-07-06  3158.75  22714.44
# 2020-07-07  3125.00  22614.69
# 2020-07-08  3154.50  22438.65
# 2020-07-09  3131.75  22529.29
# 2020-07-10  3168.25  22290.81
#
# [5369 rows x 2 columns]

# %%
plt.scatter(Nikkei_SP500[SP500],Nikkei_SP500[Nikkei])
plt.show()
