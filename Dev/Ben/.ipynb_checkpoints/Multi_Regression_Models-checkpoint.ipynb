# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import scipy.stats as sts
# import quandl
import os
import numpy as np
from scipy import stats
from scipy.stats import linregress
from scipy.stats import pearsonr
import seaborn as sn

import quandl
from config import api_key

# %% [markdown]
# ## SP500 Data

# %%
SP500 = pd.read_csv('SP500.csv')
del SP500['Change']
del SP500['High']
del SP500['Low']
del SP500['Settle']
del SP500['Previous Day Open Interest']
SP500.rename(columns={'Last':'Close'}, inplace=True)
SP500['Date']= pd.to_datetime(SP500['Date'])


# Calculate 10day MA on Price and Volume
SP500['10day_MA'] = SP500['Close'].rolling(window=10).mean()
SP500['10day_MA_Volume'] = SP500['Volume'].rolling(window=10).mean()


SP500.dropna()
# Out:
#            Date     Open    Close  Volume  10day_MA  10day_MA_Volume
# 9    1997-09-22   974.50   976.75     5.0   947.000           9735.7
# 10   1997-09-23   975.00   972.25    11.0   949.825           9647.2
# 11   1997-09-24   979.25   964.75    13.0   953.800           8422.4
# 12   1997-09-25   965.00   956.75    16.0   957.650           7448.1
# 13   1997-09-26   962.75   963.50    24.0   960.625           5600.9
# ...         ...      ...      ...     ...       ...              ...
# 5815 2020-07-16  3212.50  3185.75   929.0  3156.100           1427.8
# 5816 2020-07-17  3185.00  3203.50   740.0  3164.925           1298.7
# 5817 2020-07-20  3204.75  3233.25   851.0  3172.375           1299.7
# 5818 2020-07-21  3235.50  3239.00   945.0  3183.775           1285.5
# 5819 2020-07-22  3239.75  3256.00  1167.0  3193.925           1313.5
#
# [5811 rows x 6 columns]

# %%
SP500.Close.plot(figsize=(10,7), color='r')
plt.grid(True)
plt.show()

# %%
USD_Libor = pd.read_csv('USD_LIBOR.csv')
JPY_Libor = pd.read_csv('JPY_LIBOR.csv')

# %%
JPY_Libor.shape
# Out:
# (8726, 2)

# %%
USD_Libor['Date']= pd.to_datetime(USD_Libor['Date'])

# %%
JPY_Libor['Date']= pd.to_datetime(JPY_Libor['Date'])

# %%
USD_JPY_Rates_df = pd.merge(USD_Libor,JPY_Libor,on=['Date'])

# %%
USD_JPY_Rates_df['USD/JPY_Spread'] = USD_JPY_Rates_df['USD_3M_LIBOR'] - USD_JPY_Rates_df['JPY_3M_Libor']

# %%
USD_JPY_Rates_df = USD_JPY_Rates_df.loc[USD_JPY_Rates_df['Date']>='1997-10-03']

# %%
del USD_JPY_Rates_df['USD_3M_LIBOR']
del USD_JPY_Rates_df['JPY_3M_Libor']

# %%
USD_JPY_Rates_df
# Out:
#            Date  USD/JPY_Spread
# 2967 1997-10-03         5.21875
# 2968 1997-10-06         5.18750
# 2969 1997-10-07         5.18750
# 2970 1997-10-08         5.18750
# 2971 1997-10-09         5.21875
# ...         ...             ...
# 8718 2020-07-09         0.31525
# 8719 2020-07-10         0.31713
# 8720 2020-07-13         0.32250
# 8721 2020-07-14         0.31738
# 8722 2020-07-15         0.31821
#
# [5756 rows x 2 columns]

# %%
linear_reg_master_df = pd.merge(SP500,USD_JPY_Rates_df,on=['Date'])

# %%
linear_reg_master_df
# Out:
#            Date     Open    Close  Volume  10day_MA  10day_MA_Volume  \
# 0    1997-10-03   996.00   986.00     6.0   971.000             12.7
# 1    1997-10-06   989.25   989.00    21.0   972.225             14.3
# 2    1997-10-07   993.50  1000.00     1.0   975.000             13.3
# 3    1997-10-08   990.00   992.75     6.0   977.800             12.6
# 4    1997-10-09   989.00   988.50     3.0   980.975             11.3
# ...         ...      ...      ...     ...       ...              ...
# 5675 2020-07-09  3158.50  3131.75   988.0  3094.175           1914.0
# 5676 2020-07-10  3138.00  3168.25  1527.0  3104.675           1782.8
# 5677 2020-07-13  3171.75  3137.75  1450.0  3119.200           1645.2
# 5678 2020-07-14  3144.00  3173.00  2675.0  3132.900           1652.9
# 5679 2020-07-15  3199.00  3211.00  1863.0  3146.550           1584.1
#
#       USD/JPY_Spread
# 0            5.21875
# 1            5.18750
# 2            5.18750
# 3            5.18750
# 4            5.21875
# ...              ...
# 5675         0.31525
# 5676         0.31713
# 5677         0.32250
# 5678         0.31738
# 5679         0.31821
#
# [5680 rows x 7 columns]

# %% [markdown]
# ## 10 Year US Treasury Yield

# %%
UST_Curve = pd.read_csv('UST_Curve.csv')
Ten_Year = pd.DataFrame({'Date':UST_Curve['Date'],
                        'Ten_Year': UST_Curve['10 YR']
                        })
Ten_Year = Ten_Year.loc[Ten_Year['Date']>='1997-10-03']
Ten_Year['Date'] = pd.to_datetime(Ten_Year['Date'])
Ten_Year.dropna()
Ten_Year = Ten_Year.set_index('Date')

# %%
Ten_Year
# Out:
#             Ten_Year
# Date
# 1997-10-03      6.01
# 1997-10-06      5.96
# 1997-10-07      5.94
# 1997-10-08      6.08
# 1997-10-09      6.09
# ...              ...
# 2020-07-08      0.67
# 2020-07-09      0.62
# 2020-07-10      0.65
# 2020-07-13      0.64
# 2020-07-14      0.63
#
# [5697 rows x 1 columns]

# %%
linear_reg_master_df = pd.merge(linear_reg_master_df,Ten_Year,on=['Date'])

# %% [markdown]
# ## VIX

# %%
VIX = pd.read_csv('VIX.csv')
VIX['Date'] = pd.to_datetime(VIX['Date'])
VIX = VIX.loc[VIX['Date']>='1997-10-03']
VIX.dropna()
# Out:
#            Date    VIX
# 1961 1997-10-03  21.54
# 1962 1997-10-06  21.61
# 1963 1997-10-07  20.29
# 1964 1997-10-08  20.77
# 1965 1997-10-09  22.31
# ...         ...    ...
# 7686 2020-07-06  27.94
# 7687 2020-07-07  29.43
# 7688 2020-07-08  28.08
# 7689 2020-07-09  29.26
# 7690 2020-07-10  27.29
#
# [5730 rows x 2 columns]

# %%
linear_reg_master_df = pd.merge(linear_reg_master_df,VIX,on=['Date'])

# %% [markdown]
# ## USD/JPY Data

# %%
USDJPY = pd.read_csv('USDJPY.csv')
USDJPY.rename(columns={'DATE':'Date'}, inplace=True)
USDJPY.rename(columns={'DEXJPUS':'USDJPY'}, inplace=True)
USDJPY['Date'] = pd.to_datetime(USDJPY['Date'])
USDJPY = USDJPY.loc[USDJPY['Date']>='1997-10-03']
USDJPY.dropna()
# Out:
#             Date  USDJPY
# 6703  1997-10-03  121.93
# 6704  1997-10-06  121.93
# 6705  1997-10-07  122.01
# 6706  1997-10-08  121.09
# 6707  1997-10-09  121.18
# ...          ...     ...
# 12414 2020-07-06  107.50
# 12415 2020-07-07  107.53
# 12416 2020-07-08  107.39
# 12417 2020-07-09  107.27
# 12418 2020-07-10  106.77
#
# [5716 rows x 2 columns]

# %%
linear_reg_master_df = pd.merge(linear_reg_master_df,USDJPY,on=['Date'])

# %% [markdown]
# ## Nikkei Data

# %%
Nikkei = pd.read_csv('Nikkei.csv')
Nikkei['Date'] = pd.to_datetime(Nikkei['Date'])
Nikkei.rename(columns={'Value':'Nikkei'}, inplace=True)
Nikkei = Nikkei.loc[Nikkei['Date']>='1997-10-03']
Nikkei.dropna()
# Out:
#             Date    Nikkei
# 12108 1997-10-03  17647.45
# 12109 1997-10-06  17824.78
# 12110 1997-10-07  17511.19
# 12111 1997-10-08  17619.18
# 12112 1997-10-09  17376.92
# ...          ...       ...
# 17685 2020-07-06  22714.44
# 17686 2020-07-07  22614.69
# 17687 2020-07-08  22438.65
# 17688 2020-07-09  22529.29
# 17689 2020-07-10  22290.81
#
# [5582 rows x 2 columns]

# %%
linear_reg_master_df = pd.merge(linear_reg_master_df,Nikkei,on=['Date'])

# %%
linear_reg_master_df.Ten_Year.plot(figsize=(10,7), color='g')
# linear_reg_master_df.Close.plot(figsize=(10,7), color='g')
plt.grid(True)
plt.show()

# %%
linear_reg_master_df['Nikkei_next_day'] = linear_reg_master_df['Nikkei'].shift(-1)
linear_reg_master_df = linear_reg_master_df.dropna()
linear_reg_master_df
# Out:
#            Date     Open    Close  Volume  10day_MA  10day_MA_Volume  \
# 0    1997-10-03   996.00   986.00     6.0   971.000             12.7
# 1    1997-10-06   989.25   989.00    21.0   972.225             14.3
# 2    1997-10-07   993.50  1000.00     1.0   975.000             13.3
# 3    1997-10-08   990.00   992.75     6.0   977.800             12.6
# 4    1997-10-09   989.00   988.50     3.0   980.975             11.3
# ...         ...      ...      ...     ...       ...              ...
# 5277 2020-07-02  3092.25  3115.25  2031.0  3067.325         192980.1
# 5278 2020-07-06  3115.25  3158.75   841.0  3077.425           2525.0
# 5279 2020-07-07  3158.25  3125.00  1087.0  3079.825           2319.3
# 5280 2020-07-08  3124.75  3154.50   887.0  3085.000           2191.3
# 5281 2020-07-09  3158.50  3131.75   988.0  3094.175           1914.0
#
#       USD/JPY_Spread  Ten_Year    VIX  USDJPY    Nikkei  Nikkei_next_day
# 0            5.21875      6.01  21.54  121.93  17647.45         17824.78
# 1            5.18750      5.96  21.61  121.93  17824.78         17511.19
# 2            5.18750      5.94  20.29  122.01  17511.19         17619.18
# 3            5.18750      6.08  20.77  121.09  17619.18         17376.92
# 4            5.21875      6.09  22.31  121.18  17376.92         17306.39
# ...              ...       ...    ...     ...       ...              ...
# 5277         0.35075      0.68  27.68  107.55  22145.96         22714.44
# 5278         0.32367      0.69  27.94  107.50  22714.44         22614.69
# 5279         0.31571      0.65  29.43  107.53  22614.69         22438.65
# 5280         0.32205      0.67  28.08  107.39  22438.65         22529.29
# 5281         0.31525      0.62  29.26  107.27  22529.29         22290.81
#
# [5282 rows x 12 columns]

# %%
linear_reg_master_df.to_csv('multi_linear_reg.csv')

# %%
linear_reg_master_df.corr()
# Out:
#                      Open     Close    Volume  10day_MA  10day_MA_Volume  \
# Open             1.000000  0.999499  0.054648  0.999012         0.077981
# Close            0.999499  1.000000  0.054800  0.998714         0.077964
# Volume           0.054648  0.054800  1.000000  0.058495         0.521061
# 10day_MA         0.999012  0.998714  0.058495  1.000000         0.080072
# 10day_MA_Volume  0.077981  0.077964  0.521061  0.080072         1.000000
# USD/JPY_Spread  -0.140661 -0.140998 -0.128688 -0.139856        -0.170195
# Ten_Year        -0.564637 -0.564739 -0.146670 -0.564461        -0.201725
# VIX             -0.363762 -0.367567  0.049377 -0.352650         0.046666
# USDJPY           0.054405  0.054403 -0.119385  0.055217        -0.158231
# Nikkei           0.837912  0.837727 -0.013176  0.836961        -0.007885
# Nikkei_next_day  0.837816  0.838262 -0.012531  0.836881        -0.006712
#
#                  USD/JPY_Spread  Ten_Year       VIX    USDJPY    Nikkei  \
# Open                  -0.140661 -0.564637 -0.363762  0.054405  0.837912
# Close                 -0.140998 -0.564739 -0.367567  0.054403  0.837727
# Volume                -0.128688 -0.146670  0.049377 -0.119385 -0.013176
# 10day_MA              -0.139856 -0.564461 -0.352650  0.055217  0.836961
# 10day_MA_Volume       -0.170195 -0.201725  0.046666 -0.158231 -0.007885
# USD/JPY_Spread         1.000000  0.796449  0.040384  0.530571  0.305330
# Ten_Year               0.796449  1.000000  0.112772  0.472317 -0.116972
# VIX                    0.040384  0.112772  1.000000 -0.056948 -0.363384
# USDJPY                 0.530571  0.472317 -0.056948  1.000000  0.405102
# Nikkei                 0.305330 -0.116972 -0.363384  0.405102  1.000000
# Nikkei_next_day        0.304209 -0.117997 -0.367452  0.404625  0.998751
#
#                  Nikkei_next_day
# Open                    0.837816
# Close                   0.838262
# Volume                 -0.012531
# 10day_MA                0.836881
# 10day_MA_Volume        -0.006712
# USD/JPY_Spread          0.304209
# Ten_Year               -0.117997
# VIX                    -0.367452
# USDJPY                  0.404625
# Nikkei                  0.998751
# Nikkei_next_day         1.000000

# %% [markdown]
# ## Linear Regression Model

# %%
X = linear_reg_master_df[['USD/JPY_Spread','Close','USDJPY','10day_MA_Volume','VIX']]

# %%
y = linear_reg_master_df[['Nikkei_next_day']]

# %% [markdown]
# # Splitting Training/Testing Data

# %%
split = int(0.8*len(linear_reg_master_df))

# %%
# Training Data Set
X_train = X[:split]
y_train = y[:split]

# Testing data set
X_test = X[split:]
y_test = y[split:]

# %% [markdown]
# ## Fitting the Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)


# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
print(f"Training Score: {training_score}")
print(f"Training Score: {testing_score}")
# Out:
# Training Score: 0.8651969994764959
# Training Score: -0.8201178507645677

# %%
X_test
# Out:
#       USD/JPY_Spread    Close  USDJPY  10day_MA_Volume    VIX
# 4225         0.41271  2037.00  121.86          79444.2  19.61
# 4226         0.42414  2042.75  121.44         157411.5  19.34
# 4227         0.43557  1998.75  120.94         391149.9  24.39
# 4228         0.44275  2011.50  120.57         654394.4  22.73
# 4229         0.44646  2037.50  121.66         867078.7  20.95
# ...              ...      ...     ...              ...    ...
# 5277         0.35075  3115.25  107.55         192980.1  27.68
# 5278         0.32367  3158.75  107.50           2525.0  27.94
# 5279         0.31571  3125.00  107.53           2319.3  29.43
# 5280         0.32205  3154.50  107.39           2191.3  28.08
# 5281         0.31525  3131.75  107.27           1914.0  29.26
#
# [1057 rows x 5 columns]

# %%
y_test
# Out:
#       Nikkei_next_day
# 4225         19046.55
# 4226         19230.48
# 4227         18883.42
# 4228         18565.90
# 4229         19049.91
# ...               ...
# 5277         22714.44
# 5278         22614.69
# 5279         22438.65
# 5280         22529.29
# 5281         22290.81
#
# [1057 rows x 1 columns]

# %% [markdown]
# ## Nikkei Price Prediction

# %%
predicted_price = model.predict(X_train)
mse = mean_squared_error(y_train, predicted_price)
r2 = r2_score(y_train, predicted_price)

# %%
model.score(X_test,y_test)
# Out:
# -0.8201178507645677

# %%
predicted_price
# Out:
# array([[13477.31921394],
#        [13477.62567517],
#        [13562.57336633],
#        ...,
#        [18601.92632725],
#        [18572.33841362],
#        [18404.30315168]])

# %%
y_test
# Out:
#       Nikkei_next_day
# 4225         19046.55
# 4226         19230.48
# 4227         18883.42
# 4228         18565.90
# 4229         19049.91
# ...               ...
# 5277         22714.44
# 5278         22614.69
# 5279         22438.65
# 5280         22529.29
# 5281         22290.81
#
# [1057 rows x 1 columns]

# %%
reg_data = pd.read_csv('multi_linear_reg.csv')

# %%
del reg_data['Unnamed: 0']
reg_data['Date'] = pd.to_datetime(reg_data['Date'])

# %%
reg_data
# Out:
#            Date     Open    Close  Volume  10day_MA  10day_MA_Volume  \
# 0    1997-10-03   996.00   986.00     6.0   971.000             12.7
# 1    1997-10-06   989.25   989.00    21.0   972.225             14.3
# 2    1997-10-07   993.50  1000.00     1.0   975.000             13.3
# 3    1997-10-08   990.00   992.75     6.0   977.800             12.6
# 4    1997-10-09   989.00   988.50     3.0   980.975             11.3
# ...         ...      ...      ...     ...       ...              ...
# 5277 2020-07-02  3092.25  3115.25  2031.0  3067.325         192980.1
# 5278 2020-07-06  3115.25  3158.75   841.0  3077.425           2525.0
# 5279 2020-07-07  3158.25  3125.00  1087.0  3079.825           2319.3
# 5280 2020-07-08  3124.75  3154.50   887.0  3085.000           2191.3
# 5281 2020-07-09  3158.50  3131.75   988.0  3094.175           1914.0
#
#       USD/JPY_Spread  Ten_Year    VIX  USDJPY    Nikkei  Nikkei_next_day
# 0            5.21875      6.01  21.54  121.93  17647.45         17824.78
# 1            5.18750      5.96  21.61  121.93  17824.78         17511.19
# 2            5.18750      5.94  20.29  122.01  17511.19         17619.18
# 3            5.18750      6.08  20.77  121.09  17619.18         17376.92
# 4            5.21875      6.09  22.31  121.18  17376.92         17306.39
# ...              ...       ...    ...     ...       ...              ...
# 5277         0.35075      0.68  27.68  107.55  22145.96         22714.44
# 5278         0.32367      0.69  27.94  107.50  22714.44         22614.69
# 5279         0.31571      0.65  29.43  107.53  22614.69         22438.65
# 5280         0.32205      0.67  28.08  107.39  22438.65         22529.29
# 5281         0.31525      0.62  29.26  107.27  22529.29         22290.81
#
# [5282 rows x 12 columns]

# %%
reg_data = reg_data[['USD/JPY_Spread','Close','USDJPY','10day_MA_Volume','VIX','Nikkei_next_day']]

# %%
reg_data
# Out:
#       USD/JPY_Spread    Close  USDJPY  10day_MA_Volume    VIX  Nikkei_next_day
# 0            5.21875   986.00  121.93             12.7  21.54         17824.78
# 1            5.18750   989.00  121.93             14.3  21.61         17511.19
# 2            5.18750  1000.00  122.01             13.3  20.29         17619.18
# 3            5.18750   992.75  121.09             12.6  20.77         17376.92
# 4            5.21875   988.50  121.18             11.3  22.31         17306.39
# ...              ...      ...     ...              ...    ...              ...
# 5277         0.35075  3115.25  107.55         192980.1  27.68         22714.44
# 5278         0.32367  3158.75  107.50           2525.0  27.94         22614.69
# 5279         0.31571  3125.00  107.53           2319.3  29.43         22438.65
# 5280         0.32205  3154.50  107.39           2191.3  28.08         22529.29
# 5281         0.31525  3131.75  107.27           1914.0  29.26         22290.81
#
# [5282 rows x 6 columns]

# %%
reg_data['USDJPY_Returns'] = np.log(reg_data['USD/JPY_Spread'] /reg_data['USD/JPY_Spread'].shift(1))
reg_data['SP500_Daily_Return'] = np.log(reg_data['Close'] /reg_data['Close'].shift(1))

reg_data['10day_MA_Volume_Daily_Return'] = np.log(reg_data['10day_MA_Volume'] /reg_data['10day_MA_Volume'].shift(1))

reg_data['VIX_Daily_Return'] = np.log(reg_data['VIX'] /reg_data['VIX'].shift(1))
reg_data['USDJPY_Daily_Return'] = np.log(reg_data['USDJPY'] /reg_data['USDJPY'].shift(1))
# Out:
# C:\Users\bnjau\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bnjau\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bnjau\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bnjau\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bnjau\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\bnjau\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bnjau\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
reg_data = reg_data.dropna()
# Out:
#       USD/JPY_Spread    Close  USDJPY  10day_MA_Volume    VIX  \
# 0            5.21875   986.00  121.93             12.7  21.54
# 1            5.18750   989.00  121.93             14.3  21.61
# 2            5.18750  1000.00  122.01             13.3  20.29
# 3            5.18750   992.75  121.09             12.6  20.77
# 4            5.21875   988.50  121.18             11.3  22.31
# ...              ...      ...     ...              ...    ...
# 5277         0.35075  3115.25  107.55         192980.1  27.68
# 5278         0.32367  3158.75  107.50           2525.0  27.94
# 5279         0.31571  3125.00  107.53           2319.3  29.43
# 5280         0.32205  3154.50  107.39           2191.3  28.08
# 5281         0.31525  3131.75  107.27           1914.0  29.26
#
#       Nikkei_next_day  USDJPY_Returns  SP500_Daily_Return  \
# 0            17824.78             NaN                 NaN
# 1            17511.19       -0.006006            0.003038
# 2            17619.18        0.000000            0.011061
# 3            17376.92        0.000000           -0.007276
# 4            17306.39        0.006006           -0.004290
# ...               ...             ...                 ...
# 5277         22714.44        0.016529            0.008057
# 5278         22614.69       -0.080349            0.013867
# 5279         22438.65       -0.024900           -0.010742
# 5280         22529.29        0.019883            0.009396
# 5281         22290.81       -0.021341           -0.007238
#
#       10day_MA_Volume_Daily_Return  VIX_Daily_Return  USDJPY_Daily_Return
# 0                              NaN               NaN                  NaN
# 1                         0.118658          0.003244             0.000000
# 2                        -0.072496         -0.063028             0.000656
# 3                        -0.054067          0.023381            -0.007569
# 4                        -0.108894          0.071525             0.000743
# ...                            ...               ...                  ...
# 5277                     -0.608218         -0.033396             0.000465
# 5278                     -4.336346          0.009349            -0.000465
# 5279                     -0.084976          0.051955             0.000279
# 5280                     -0.056770         -0.046957            -0.001303
# 5281                     -0.135300          0.041164            -0.001118
#
# [5282 rows x 11 columns]

# %%
X = reg_data[['USDJPY_Returns','SP500_Daily_Return','10day_MA_Volume_Daily_Return','VIX_Daily_Return','USDJPY_Daily_Return']]

# %%
X.dropna()
# Out:
#       USDJPY_Returns  SP500_Daily_Return  10day_MA_Volume_Daily_Return  \
# 1          -0.006006            0.003038                      0.118658
# 2           0.000000            0.011061                     -0.072496
# 3           0.000000           -0.007276                     -0.054067
# 4           0.006006           -0.004290                     -0.108894
# 5           0.000749           -0.000506                     -0.436928
# ...              ...                 ...                           ...
# 5277        0.016529            0.008057                     -0.608218
# 5278       -0.080349            0.013867                     -4.336346
# 5279       -0.024900           -0.010742                     -0.084976
# 5280        0.019883            0.009396                     -0.056770
# 5281       -0.021341           -0.007238                     -0.135300
#
#       VIX_Daily_Return  USDJPY_Daily_Return
# 1             0.003244             0.000000
# 2            -0.063028             0.000656
# 3             0.023381            -0.007569
# 4             0.071525             0.000743
# 5            -0.109803             0.004693
# ...                ...                  ...
# 5277         -0.033396             0.000465
# 5278          0.009349            -0.000465
# 5279          0.051955             0.000279
# 5280         -0.046957            -0.001303
# 5281          0.041164            -0.001118
#
# [5278 rows x 5 columns]

# %%
y = reg_data[['Nikkei_next_day']]

# %%
y
# Out:
#       Nikkei_next_day
# 0            17824.78
# 1            17511.19
# 2            17619.18
# 3            17376.92
# 4            17306.39
# ...               ...
# 5277         22714.44
# 5278         22614.69
# 5279         22438.65
# 5280         22529.29
# 5281         22290.81
#
# [5282 rows x 1 columns]
